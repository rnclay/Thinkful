# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import warnings
import matplotlib.pyplot as plt
from scipy.stats import zscore
from scipy.stats.mstats import winsorize
from scipy import stats
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
warnings.filterwarnings('ignore')
sns.set(style="whitegrid")

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'useducation'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

edu_df = pd.read_sql_query('select * from useducation',con=engine)
engine.dispose()

# %%
edu_df.sample(5)
# Out:
#               PRIMARY_KEY           STATE  YEAR    ENROLL  TOTAL_REVENUE  \
# 1392    2004_DOD_OVERSEAS    DOD_OVERSEAS  2004       NaN            NaN
# 21     1992_MASSACHUSETTS   MASSACHUSETTS  1992       NaN      5517659.0
# 1379  2002_AMERICAN_SAMOA  AMERICAN_SAMOA  2002       NaN            NaN
# 537         2002_KENTUCKY        KENTUCKY  2002  654363.0      4621025.0
# 146     1994_SOUTH_DAKOTA    SOUTH_DAKOTA  1994  108439.0       507927.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 1392              NaN            NaN            NaN                NaN
# 21           273946.0      1439051.0      3804662.0          5245560.0
# 1379              NaN            NaN            NaN                NaN
# 537          486226.0      2743882.0      1390917.0          4541670.0
# 146           51846.0       126591.0       329490.0           525289.0
#
#       INSTRUCTION_EXPENDITURE  ...  GRADES_4_G  GRADES_8_G  GRADES_12_G  \
# ...

# %%
fill_list = ["ENROLL", "TOTAL_REVENUE", "FEDERAL_REVENUE",
             "STATE_REVENUE", "LOCAL_REVENUE", "TOTAL_EXPENDITURE",
             "INSTRUCTION_EXPENDITURE", "SUPPORT_SERVICES_EXPENDITURE",
             "OTHER_EXPENDITURE", "CAPITAL_OUTLAY_EXPENDITURE", "GRADES_PK_G",
             "GRADES_KG_G", "GRADES_4_G", "GRADES_8_G", "GRADES_12_G", "GRADES_1_8_G",
             "GRADES_9_12_G", "GRADES_ALL_G"]

states = edu_df["STATE"].unique()

for state in states:
    edu_df.loc[edu_df["STATE"] == state, fill_list] = edu_df.loc[edu_df["STATE"] == state, fill_list].interpolate()


edu_df.dropna(inplace=True)

# %% [markdown]
# **Question1:** Create a new score variable from the weighted averages of all score variables in the datasets. Notice that the number of students in the 4th grade isn't the same as the number of students in the 8th grade. So, you should appropriately weigh the scores!.

# %%
edu_df.loc[:,["GRADES_4_G","GRADES_8_G"]].sum()
# Out:
# GRADES_4_G    33792375.0
# GRADES_8_G    33979357.5
# dtype: float64

# %%
edu_df["total_score"] = (edu_df["GRADES_4_G"]*((edu_df["AVG_MATH_4_SCORE"] + edu_df["AVG_READING_4_SCORE"])*0.5) + edu_df["GRADES_8_G"]
                                 * ((edu_df["AVG_MATH_8_SCORE"] + edu_df["AVG_READING_8_SCORE"])*0.5))/(edu_df["GRADES_4_G"] + edu_df["GRADES_8_G"])

# %%
edu_df.head(5)
# Out:
#          PRIMARY_KEY       STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 209     1996_ALABAMA     ALABAMA  1996   735912.0      3365113.0
# 211     1996_ARIZONA     ARIZONA  1996   764681.0      4143304.0
# 212    1996_ARKANSAS    ARKANSAS  1996   452907.0      2183384.0
# 213  1996_CALIFORNIA  CALIFORNIA  1996  5460484.0     31282981.0
# 214    1996_COLORADO    COLORADO  1996   655679.0      3891203.0
#
#      FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 209         334858.0      2138717.0       891538.0          3572283.0
# 211         378917.0      1798363.0      1966024.0          4391555.0
# 212         192152.0      1296247.0       694985.0          2297381.0
# 213        2603882.0     17061474.0     11617625.0         31561692.0
# 214         194998.0      1664676.0      2031529.0          4075165.0
#
#      INSTRUCTION_EXPENDITURE  ...  GRADES_8_G  GRADES_12_G  GRADES_1_8_G  \
# 209                1987018.0  ...     58305.0      42510.0      469370.0
# ...

# %% [markdown]
# **Question 2:** What are the correlations between this newly created score variable and the expenditure types? Which 1 of the expenditure types is more correlated than the others?

# %%
edu_df[["total_score", "TOTAL_EXPENDITURE", "INSTRUCTION_EXPENDITURE",
              "SUPPORT_SERVICES_EXPENDITURE", "OTHER_EXPENDITURE", "CAPITAL_OUTLAY_EXPENDITURE"]].corr()
# Out:
#                               total_score  TOTAL_EXPENDITURE  \
# total_score                      1.000000           0.074155
# TOTAL_EXPENDITURE                0.074155           1.000000
# INSTRUCTION_EXPENDITURE          0.087386           0.990255
# SUPPORT_SERVICES_EXPENDITURE     0.079002           0.992988
# OTHER_EXPENDITURE                0.010959           0.943702
# CAPITAL_OUTLAY_EXPENDITURE      -0.005389           0.925784
#
#                               INSTRUCTION_EXPENDITURE  \
# total_score                                  0.087386
# TOTAL_EXPENDITURE                            0.990255
# INSTRUCTION_EXPENDITURE                      1.000000
# SUPPORT_SERVICES_EXPENDITURE                 0.974399
# OTHER_EXPENDITURE                            0.902173
# CAPITAL_OUTLAY_EXPENDITURE                   0.884798
#
#                               SUPPORT_SERVICES_EXPENDITURE  OTHER_EXPENDITURE  \
# ...

# %% [markdown]
# **Question 3:** Now, apply PCA to the 4 expenditure types. How much of the total variance is explained by the 1st component?

# %%
X = edu_df[["INSTRUCTION_EXPENDITURE", "SUPPORT_SERVICES_EXPENDITURE",
                  "OTHER_EXPENDITURE", "CAPITAL_OUTLAY_EXPENDITURE"]]

X = StandardScaler().fit_transform(X)

sklearn_pca = PCA(n_components=1)
edu_df["pca_1"] = sklearn_pca.fit_transform(X)

print(
    'The percentage of total variance in the dataset explained by each',
    'component from Sklearn PCA.\n',
    sklearn_pca.explained_variance_ratio_
)
# Out:
# The percentage of total variance in the dataset explained by each component from Sklearn PCA.
#  [0.9430175]

# %% [markdown]
# **Question 4:** What is the correlation between the overall score variable and the 1st principal component?

# %%
edu_df.head()
# Out:
#          PRIMARY_KEY       STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 209     1996_ALABAMA     ALABAMA  1996   735912.0      3365113.0
# 211     1996_ARIZONA     ARIZONA  1996   764681.0      4143304.0
# 212    1996_ARKANSAS    ARKANSAS  1996   452907.0      2183384.0
# 213  1996_CALIFORNIA  CALIFORNIA  1996  5460484.0     31282981.0
# 214    1996_COLORADO    COLORADO  1996   655679.0      3891203.0
#
#      FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 209         334858.0      2138717.0       891538.0          3572283.0
# 211         378917.0      1798363.0      1966024.0          4391555.0
# 212         192152.0      1296247.0       694985.0          2297381.0
# 213        2603882.0     17061474.0     11617625.0         31561692.0
# 214         194998.0      1664676.0      2031529.0          4075165.0
#
#      INSTRUCTION_EXPENDITURE  ...  GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  \
# ...

# %%
edu_df[["total_score","pca_1", "INSTRUCTION_EXPENDITURE"]].corr()
# Out:
#                          total_score     pca_1  INSTRUCTION_EXPENDITURE
# total_score                 1.000000  0.044596                 0.087386
# pca_1                       0.044596  1.000000                 0.968606
# INSTRUCTION_EXPENDITURE     0.087386  0.968606                 1.000000

# %% [markdown]
# **Question 5:** If you were to choose the best variables for your model, would you prefer using the 1st principal component instead of the expenditure variables? Why?
# *Instruction expenditure has a higher correlation with the total_score variable, and is highly correlated with the component analysis, so it should be used.*
