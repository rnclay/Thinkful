# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import warnings
import matplotlib.pyplot as plt
from scipy.stats import zscore
from scipy.stats.mstats import winsorize
from scipy import stats
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy.stats import boxcox
from scipy.stats import jarque_bera
from scipy.stats import normaltest
warnings.filterwarnings('ignore')
sns.set(style="whitegrid")

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'lifeexpectancy'
table_name = 'lifeexpectancy'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db,table_name))

life_df = pd.read_sql_query('select * from lifeexpectancy',con=engine)
engine.dispose()

# %%
pd.set_option('display.max_columns',None)

# %%
pd.set_option('display.max_rows',None)

# %%
life_df.describe(include = 'all')
# Out:
#                            Country         Year      Status  Life expectancy   \
# count                         2938  2938.000000        2938       2928.000000
# unique                         193          NaN           2               NaN
# top     Iran (Islamic Republic of)          NaN  Developing               NaN
# freq                            16          NaN        2426               NaN
# mean                           NaN  2007.518720         NaN         69.224932
# std                            NaN     4.613841         NaN          9.523867
# min                            NaN  2000.000000         NaN         36.300000
# 25%                            NaN  2004.000000         NaN         63.100000
# 50%                            NaN  2008.000000         NaN         72.100000
# 75%                            NaN  2012.000000         NaN         75.700000
# max                            NaN  2015.000000         NaN         89.000000
#
#         Adult Mortality  infant deaths      Alcohol  percentage expenditure  \
# count       2928.000000    2938.000000  2744.000000             2938.000000
# unique              NaN            NaN          NaN                     NaN
# top                 NaN            NaN          NaN                     NaN
# freq                NaN            NaN          NaN                     NaN
# mean         164.796448      30.303948     4.602861              738.251295
# std          124.292079     117.926501     4.052413             1987.914858
# min            1.000000       0.000000     0.010000                0.000000
# 25%           74.000000       0.000000     0.877500                4.685343
# 50%          144.000000       3.000000     3.755000               64.912906
# 75%          228.000000      22.000000     7.702500              441.534144
# max          723.000000    1800.000000    17.870000            19479.911610
#
#         Hepatitis B       Measles          BMI   under-five deaths   \
# count   2385.000000    2938.000000  2904.000000         2938.000000
# unique          NaN            NaN          NaN                 NaN
# top             NaN            NaN          NaN                 NaN
# freq            NaN            NaN          NaN                 NaN
# mean      80.940461    2419.592240    38.321247           42.035739
# std       25.070016   11467.272489    20.044034          160.445548
# min        1.000000       0.000000     1.000000            0.000000
# 25%       77.000000       0.000000    19.300000            0.000000
# 50%       92.000000      17.000000    43.500000            4.000000
# 75%       97.000000     360.250000    56.200000           28.000000
# max       99.000000  212183.000000    87.300000         2500.000000
#
#               Polio  Total expenditure  Diphtheria      HIV/AIDS  \
# count   2919.000000         2712.00000  2919.000000  2938.000000
# unique          NaN                NaN          NaN          NaN
# top             NaN                NaN          NaN          NaN
# freq            NaN                NaN          NaN          NaN
# mean      82.550188            5.93819    82.324084     1.742103
# std       23.428046            2.49832    23.716912     5.077785
# min        3.000000            0.37000     2.000000     0.100000
# 25%       78.000000            4.26000    78.000000     0.100000
# 50%       93.000000            5.75500    93.000000     0.100000
# 75%       97.000000            7.49250    97.000000     0.800000
# max       99.000000           17.60000    99.000000    50.600000
#
#                   GDP    Population   thinness  1-19 years  \
# count     2490.000000  2.286000e+03            2904.000000
# unique            NaN           NaN                    NaN
# top               NaN           NaN                    NaN
# freq              NaN           NaN                    NaN
# mean      7483.158469  1.275338e+07               4.839704
# std      14270.169342  6.101210e+07               4.420195
# min          1.681350  3.400000e+01               0.100000
# 25%        463.935626  1.957932e+05               1.600000
# 50%       1766.947595  1.386542e+06               3.300000
# 75%       5910.806335  7.420359e+06               7.200000
# max     119172.741800  1.293859e+09              27.700000
#
#          thinness 5-9 years  Income composition of resources    Schooling
# count           2904.000000                      2771.000000  2775.000000
# unique                  NaN                              NaN          NaN
# top                     NaN                              NaN          NaN
# freq                    NaN                              NaN          NaN
# mean               4.870317                         0.627551    11.992793
# std                4.508882                         0.210904     3.358920
# min                0.100000                         0.000000     0.000000
# 25%                1.500000                         0.493000    10.100000
# 50%                3.300000                         0.677000    12.300000
# 75%                7.200000                         0.779000    14.300000
# max               28.600000                         0.948000    20.700000

# %%
life_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Status                             2938 non-null object
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
#  HIV/AIDS                          2938 non-null float64
# GDP                                2490 non-null float64
# Population                         2286 non-null float64
#  thinness  1-19 years              2904 non-null float64
#  thinness 5-9 years                2904 non-null float64
# Income composition of resources    2771 non-null float64
# Schooling                          2775 non-null float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 482.1+ KB

# %%
life_df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# 0   19.1                  83    6.0               8.16         65.0
# 1   18.6                  86   58.0               8.18         62.0
# 2   18.1                  89   62.0               8.13         64.0
# 3   17.6                  93   67.0               8.52         67.0
# 4   17.2                  97   68.0               7.87         68.0
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling
# 0                 17.3                            0.479       10.1
# 1                 17.5                            0.476       10.0
# 2                 17.7                            0.470        9.9
# 3                 18.0                            0.463        9.8
# 4                 18.2                            0.454        9.5

# %%
life_df.rename(str.lower, axis = 'columns', inplace = True)

# %%
life_df.columns = life_df.columns.str.strip()

# %%
life_df.nunique()
# Out:
# country                             193
# year                                 16
# status                                2
# life expectancy                     362
# adult mortality                     425
# infant deaths                       209
# alcohol                            1076
# percentage expenditure             2328
# hepatitis b                          87
# measles                             958
# bmi                                 608
# under-five deaths                   252
# polio                                73
# total expenditure                   818
# diphtheria                           81
# hiv/aids                            200
# gdp                                2490
# population                         2278
# thinness  1-19 years                200
# thinness 5-9 years                  207
# income composition of resources     625
# schooling                           173
# dtype: int64

# %%
life_df.sample(20)
# Out:
#                                country  year      status  life expectancy  \
# 2267                            Serbia  2014  Developing             75.4
# 307   Bolivia (Plurinational State of)  2013  Developing             71.0
# 2615                       Timor-Leste  2001  Developing             59.4
# 1271                            Israel  2011  Developing             81.8
# 2287                        Seychelles  2010  Developing             72.4
# 1171                           Iceland  2015   Developed             82.7
# 807                              Egypt  2010  Developing             70.0
# 2284                        Seychelles  2013  Developing             72.9
# 494                           Cameroon  2001  Developing             51.5
# 2853                           Vanuatu  2004  Developing             69.6
# 1083                            Guinea  2007  Developing             56.4
# 2459                             Sudan  2013  Developing             63.5
# 1577                            Malawi  2009  Developing             51.5
# 954                              Gabon  2008  Developing             61.6
# 41                             Algeria  2007  Developing             73.8
# 2475                          Suriname  2013  Developing             71.2
# 288                              Benin  2000  Developing             55.4
# 778                 Dominican Republic  2007  Developing             72.9
# 2127                           Romania  2008   Developed             73.1
# 729   Democratic Republic of the Congo  2007  Developing             55.7
#
#       adult mortality  infant deaths  alcohol  percentage expenditure  \
# 2267            123.0              1     9.09                8.617208
# 307             192.0              8     3.78                0.000000
# 2615            269.0              3     0.50                6.556583
# 1271             61.0              1     2.67             3793.161624
# 2287             18.0              0     6.51               16.492323
# 1171             49.0              0      NaN                0.000000
# 807             173.0             54     0.22                0.000000
# 2284            172.0              0     0.01             1521.672751
# 494              41.0             61     4.43               41.736292
# 2853            169.0              0     0.85              334.167337
# 1083             36.0             31     0.19                1.399627
# 2459            232.0             60     0.01              227.835321
# 1577            491.0             36     1.16                7.915071
# 954             298.0              2     8.75               11.054225
# 41              129.0             20     0.44              320.323924
# 2475            179.0              0     6.02             1122.972967
# 288             279.0             25     1.34               37.381820
# 778             164.0              6     6.05               74.821749
# 2127            159.0              2    11.90              128.080570
# 729             299.0            236     1.52                0.000000
#
#       hepatitis b  measles   bmi  under-five deaths  polio  total expenditure  \
# 2267         92.0       37  59.4                  1   93.0               1.37
# 307          94.0        0  51.2                 10   95.0               5.96
# 2615          NaN        0  12.3                  4    NaN               3.75
# 1271         98.0       70  63.4                  1   94.0               7.39
# 2287         99.0        0  33.5                  0   99.0               3.59
# 1171          NaN        0  61.0                  0   92.0                NaN
# 807          97.0       16  57.0                 64   97.0               4.80
# 2284         99.0        0  35.5                  0   98.0               3.58
# 494           NaN    23934  21.3                 99   61.0               4.70
# 2853         63.0        0  44.1                  0   67.0               4.12
# 1083         57.0        3  19.4                 48   46.0               3.80
# 2459         93.0     2813   NaN                 88   93.0               8.42
# 1577         93.0       21  17.3                 56   93.0               1.18
# 954          82.0        3  32.4                  3   81.0               2.54
# 41            9.0        0   5.8                 23   95.0               3.82
# 2475         86.0        0  57.0                  0   86.0               5.96
# 288           NaN     4244  18.4                 40   78.0               4.34
# 778          81.0        0   5.4                  8   86.0               4.34
# 2127         97.0       12  55.6                  3   95.0               5.33
# 729           7.0    55577  17.8                326   72.0               3.61
#
#       diphtheria  hiv/aids           gdp  population  thinness  1-19 years  \
# 2267        93.0       0.1     62.173221    713576.0                   2.1
# 307         94.0       0.1           NaN         NaN                   1.2
# 2615         NaN       0.1     56.424987    892531.0                  12.1
# 1271        94.0       0.1  33657.157270     77658.0                   1.2
# 2287        99.0       0.1    184.684470      8977.0                   5.8
# 1171        92.0       0.1   5734.443600     33815.0                   1.0
# 807         97.0       0.1           NaN         NaN                   3.0
# 2284        98.0       0.1  15687.347950     89949.0                   5.7
# 494         63.0       7.9    614.672934  15671927.0                   7.5
# 2853        69.0       0.1   1787.947230     24143.0                   1.6
# 1083        63.0       2.4     49.456775    196727.0                   8.9
# 2459        93.0       0.3   1955.667990  36849918.0                   NaN
# 1577        93.0      14.9     42.737966   1471462.0                   6.9
# 954         82.0       8.9    194.274600   1536411.0                   6.8
# 41          95.0       0.1   3935.183343     34376.0                   6.0
# 2475        86.0       0.4   9484.568980     54254.0                   3.5
# 288         78.0       2.0    374.192394   6865951.0                   9.7
# 778         85.0       1.6   4647.313590    954353.0                   3.4
# 2127        96.0       0.1   1136.473560   2537875.0                   3.1
# 729          7.0       1.9           NaN         NaN                  11.1
#
#       thinness 5-9 years  income composition of resources  schooling
# 2267                 2.1                            0.771       14.3
# 307                  1.1                            0.661       13.8
# 2615                12.2                            0.470        9.8
# 1271                 1.1                            0.883       15.8
# 2287                 6.2                            0.740       13.2
# 1171                 0.9                            0.919       19.0
# 807                  2.9                            0.665       12.2
# 2284                 6.1                            0.762       13.5
# 494                  7.7                            0.437        7.1
# 2853                 1.5                            0.000       10.7
# 1083                 8.8                            0.364        7.6
# 2459                 NaN                            0.478        7.0
# 1577                 6.8                            0.415        9.9
# 954                  6.6                            0.651       12.4
# 41                   5.9                            0.690       12.3
# 2475                 3.5                            0.719       12.7
# 288                  9.6                            0.389        6.4
# 778                  3.4                            0.685       12.7
# 2127                 3.5                            0.780       14.7
# 729                  1.9                              NaN        NaN

# %% [markdown]
# Detecting **missing values**

# %%
life_df.isna().sum()*100/life_df.isna().count()
# Out:
# country                             0.000000
# year                                0.000000
# status                              0.000000
# life expectancy                     0.340368
# adult mortality                     0.340368
# infant deaths                       0.000000
# alcohol                             6.603131
# percentage expenditure              0.000000
# hepatitis b                        18.822328
# measles                             0.000000
# bmi                                 1.157250
# under-five deaths                   0.000000
# polio                               0.646698
# total expenditure                   7.692308
# diphtheria                          0.646698
# hiv/aids                            0.000000
# gdp                                15.248468
# population                         22.191967
# thinness  1-19 years                1.157250
# thinness 5-9 years                  1.157250
# income composition of resources     5.684139
# schooling                           5.547992
# dtype: float64

# %%
empty_values = ["alcohol", "hepatitis b","total expenditure","gdp","population",
               "income composition of resources","schooling"]
for column_name in empty_values:
    print("Unique values in column {} are: {}".format(column_name, life_df[column_name].unique()))
# Out:
# Unique values in column alcohol are: [0.01 0.03 0.02 ... 2.44 3.56 4.57]
# Unique values in column hepatitis b are: [65. 62. 64. 67. 68. 66. 63. 99. 98. 97. 96. 95.  1. 94. 91.  9.  8. 83.
#  81. nan 77. 75. 72. 61. 69. 73. 85. 84. 88. 93. 89. 78. 55. 92. 86. 44.
#  33. 74. 52. 49.  5. 51. 21. 45. 11. 87. 18. 56.  7.  6. 76. 82. 79. 15.
#  36. 48.  4. 42. 28. 14. 47. 23. 46. 37. 39. 24. 17. 27. 25. 16.  2. 35.
#  29. 26. 54. 57. 38. 59. 71. 43. 58. 41. 31. 12. 32. 22. 53. 19.]
# Unique values in column total expenditure are: [ 8.16  8.18  8.13  8.52  7.87  9.2   9.42  8.33  6.73  7.43  8.7   8.79
#   8.82  7.76  7.8   8.2   6.    5.88  5.66  5.59  5.71  5.34  5.79  5.87
#   6.1   5.86  6.12  6.38  6.27  6.3   6.26   nan  7.21  7.12  6.14  5.29
#   4.85  5.12  5.36  4.2   3.82  3.36  3.24  3.54  3.6   3.73  3.84  3.49
#  16.5 16.3 16.1 16.4 15.6 15.  12.7 11.9 11.2 20.4 20.3 20.1 19.8 19.5
#  19.1 19.  20.7 20.6 20.5 15.9 15.7 15.4 15.3 15.1 15.2 14.9 15.5 11.8
#  11.  10.4 12.4 12.1 13.7 13.5 13.2 10.2  8.6  8.2  7.5  7.3 15.8 14.8
#  14.6 16.6 16.2 18.8 18.6 18.2 18.  12.8 12.9  9.3  9.1  6.6 10.5  9.6
#   8.8  8.   7.6 14.3 13.4  6.7  6.3  5.4  4.9  4.7  4.3  3.9  3.8  3.6
#   3.5  3.4  5.6  5.2  4.4  4.5 11.3  9.7  8.3  7.1  6.9  6.   5.7  5.3
#  13.  17.6 17.7 16.  19.2 18.7 18.4 16.9 16.7  5.   4.   3.7  3.3  2.9
#   5.8 17.  18.3 18.1  7.8  7.   4.8  7.4 17.9 18.5 17.5  6.1 19.3 19.7
#  18.9 17.4  4.2  3.1  3.   2.8]

# %%
for column_name in empty_values:
    print("These are the problematic values for the variable: {}".format(column_name))
    for value in life_df[column_name]:
        try:
            float(value)
        except:
            print(value)
# Out:
# These are the problematic values for the variable: alcohol
# These are the problematic values for the variable: hepatitis b
# These are the problematic values for the variable: total expenditure
# These are the problematic values for the variable: gdp
# These are the problematic values for the variable: population
# These are the problematic values for the variable: income composition of resources
# These are the problematic values for the variable: schooling

# %%
corrmat_life = life_df.corr()
plt.figure(figsize=(18,15))

sns.heatmap(corrmat_life, square=True,annot=True,linewidth=.5)
plt.title("Correlation matrix with nan values")
plt.show()

# %% [markdown]
# I filled the missing values with **median** or **mean**.

# %%
life_df["alcohol"].describe()
# Out:
# count    2744.000000
# mean        4.602861
# std         4.052413
# min         0.010000
# 25%         0.877500
# 50%         3.755000
# 75%         7.702500
# max        17.870000
# Name: alcohol, dtype: float64

# %%
life_df["alcohol"].fillna(life_df["alcohol"].median(), inplace=True)

# %%
life_df["hepatitis b"].describe()
# Out:
# count    2385.000000
# mean       80.940461
# std        25.070016
# min         1.000000
# 25%        77.000000
# 50%        92.000000
# 75%        97.000000
# max        99.000000
# Name: hepatitis b, dtype: float64

# %%
life_df["hepatitis b"].fillna(life_df["hepatitis b"].mean(),inplace=True)

# %%
life_df["total expenditure"].describe()
# Out:
# count    2712.00000
# mean        5.93819
# std         2.49832
# min         0.37000
# 25%         4.26000
# 50%         5.75500
# 75%         7.49250
# max        17.60000
# Name: total expenditure, dtype: float64

# %%
life_df["total expenditure"].fillna(life_df["total expenditure"].mean(),inplace=True)

# %%
life_df["gdp"].describe()
# Out:
# count      2490.000000
# mean       7483.158469
# std       14270.169342
# min           1.681350
# 25%         463.935626
# 50%        1766.947595
# 75%        5910.806335
# max      119172.741800
# Name: gdp, dtype: float64

# %%
life_df["gdp"].fillna(life_df["gdp"].median(),inplace=True)

# %%
life_df["population"].describe()
# Out:
# count    2.286000e+03
# mean     1.275338e+07
# std      6.101210e+07
# min      3.400000e+01
# 25%      1.957932e+05
# 50%      1.386542e+06
# 75%      7.420359e+06
# max      1.293859e+09
# Name: population, dtype: float64

# %%
life_df["population"].fillna(life_df["population"].mean(),inplace=True)

# %%
life_df["income composition of resources"].describe()
# Out:
# count    2771.000000
# mean        0.627551
# std         0.210904
# min         0.000000
# 25%         0.493000
# 50%         0.677000
# 75%         0.779000
# max         0.948000
# Name: income composition of resources, dtype: float64

# %%
life_df["income composition of resources"].fillna(life_df["income composition of resources"].mean(),inplace=True)

# %%
life_df["schooling"].describe()
# Out:
# count    2775.000000
# mean       11.992793
# std         3.358920
# min         0.000000
# 25%        10.100000
# 50%        12.300000
# 75%        14.300000
# max        20.700000
# Name: schooling, dtype: float64

# %%
life_df["schooling"].fillna(life_df["schooling"].mean(), inplace=True)

# %%
life_df["life expectancy"].fillna(life_df["life expectancy"].mean(),inplace=True)
life_df["adult mortality"].fillna(life_df["adult mortality"].mean(),inplace=True)
life_df["bmi"].fillna(life_df["bmi"].mean(),inplace=True)
life_df["polio"].fillna(life_df["polio"].mean(),inplace=True)
life_df["diphtheria"].fillna(life_df["diphtheria"].mean(),inplace=True)
life_df["thinness  1-19 years"].fillna(life_df["thinness  1-19 years"].mean(),inplace=True)
life_df["thinness 5-9 years"].fillna(life_df["thinness 5-9 years"].mean(),inplace=True)

# %%
life_df.isna().sum()*100/life_df.isna().count()
# Out:
# country                            0.0
# year                               0.0
# status                             0.0
# life expectancy                    0.0
# adult mortality                    0.0
# infant deaths                      0.0
# alcohol                            0.0
# percentage expenditure             0.0
# hepatitis b                        0.0
# measles                            0.0
# bmi                                0.0
# under-five deaths                  0.0
# polio                              0.0
# total expenditure                  0.0
# diphtheria                         0.0
# hiv/aids                           0.0
# gdp                                0.0
# population                         0.0
# thinness  1-19 years               0.0
# thinness 5-9 years                 0.0
# income composition of resources    0.0
# schooling                          0.0
# dtype: float64

# %%
corrmat_life = life_df.corr()
plt.figure(figsize=(18,15))

sns.heatmap(corrmat_life, square=True,annot=True,linewidth=.5)
plt.title("Correlation matrix no null values")
plt.show()

# %% [markdown]
# I used the **Tukey's Method** to identify outliers.

# %%
q75, q25 = np.percentile(life_df.iloc[:,3:20], [75 ,25])
iqr = q75 - q25

for column_name in life_df.iloc[:,3:20]:
    print("-----------------------------------------")
    print("In {}:".format(column_name))
    print("-----------------------------------------")
    for threshold in np.arange(1,5,0.5):
        min_val = q25 - (iqr*threshold)
        max_val = q75 + (iqr*threshold)
        print("The score threshold is: {}".format(threshold))
        print("Number of outliers is: {}".format(
        len((np.where((life_df[column_name] > max_val) 
                      | (life_df[column_name] < min_val))[0]))
    ))
# Out:
# -----------------------------------------
# In life expectancy:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# -----------------------------------------
# In adult mortality:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 953
# The score threshold is: 1.5
# Number of outliers is: 673
# The score threshold is: 2.0
# Number of outliers is: 444
# The score threshold is: 2.5
# Number of outliers is: 310
# The score threshold is: 3.0
# Number of outliers is: 185
# The score threshold is: 3.5
# Number of outliers is: 127
# The score threshold is: 4.0
# Number of outliers is: 75
# The score threshold is: 4.5
# Number of outliers is: 50
# -----------------------------------------
# In infant deaths:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 88
# The score threshold is: 1.5
# Number of outliers is: 65
# The score threshold is: 2.0
# Number of outliers is: 56
# The score threshold is: 2.5
# Number of outliers is: 54
# The score threshold is: 3.0
# Number of outliers is: 37
# The score threshold is: 3.5
# Number of outliers is: 34
# The score threshold is: 4.0
# Number of outliers is: 33
# The score threshold is: 4.5
# Number of outliers is: 27
# -----------------------------------------
# In alcohol:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# -----------------------------------------
# In percentage expenditure:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 1069
# The score threshold is: 1.5
# Number of outliers is: 978
# The score threshold is: 2.0
# Number of outliers is: 907
# The score threshold is: 2.5
# Number of outliers is: 853
# The score threshold is: 3.0
# Number of outliers is: 793
# The score threshold is: 3.5
# Number of outliers is: 753
# The score threshold is: 4.0
# Number of outliers is: 706
# The score threshold is: 4.5
# Number of outliers is: 661
# -----------------------------------------
# In hepatitis b:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# -----------------------------------------
# In measles:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 883
# The score threshold is: 1.5
# Number of outliers is: 830
# The score threshold is: 2.0
# Number of outliers is: 798
# The score threshold is: 2.5
# Number of outliers is: 761
# The score threshold is: 3.0
# Number of outliers is: 721
# The score threshold is: 3.5
# Number of outliers is: 701
# The score threshold is: 4.0
# Number of outliers is: 674
# The score threshold is: 4.5
# Number of outliers is: 659
# -----------------------------------------
# In bmi:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# -----------------------------------------
# In under-five deaths:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 111
# The score threshold is: 1.5
# Number of outliers is: 92
# The score threshold is: 2.0
# Number of outliers is: 84
# The score threshold is: 2.5
# Number of outliers is: 65
# The score threshold is: 3.0
# Number of outliers is: 56
# The score threshold is: 3.5
# Number of outliers is: 53
# The score threshold is: 4.0
# Number of outliers is: 38
# The score threshold is: 4.5
# Number of outliers is: 34
# -----------------------------------------
# In polio:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# -----------------------------------------
# In total expenditure:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# -----------------------------------------
# In diphtheria:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# -----------------------------------------
# In hiv/aids:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# -----------------------------------------
# In gdp:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 2651
# The score threshold is: 1.5
# Number of outliers is: 2602
# The score threshold is: 2.0
# Number of outliers is: 2539
# The score threshold is: 2.5
# Number of outliers is: 2492
# The score threshold is: 3.0
# Number of outliers is: 2421
# The score threshold is: 3.5
# Number of outliers is: 2369
# The score threshold is: 4.0
# Number of outliers is: 2307
# The score threshold is: 4.5
# Number of outliers is: 2264
# -----------------------------------------
# In population:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 2931
# The score threshold is: 1.5
# Number of outliers is: 2931
# The score threshold is: 2.0
# Number of outliers is: 2931
# The score threshold is: 2.5
# Number of outliers is: 2925
# The score threshold is: 3.0
# Number of outliers is: 2920
# The score threshold is: 3.5
# Number of outliers is: 2917
# The score threshold is: 4.0
# Number of outliers is: 2912
# The score threshold is: 4.5
# Number of outliers is: 2911
# -----------------------------------------
# In thinness  1-19 years:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# -----------------------------------------
# In thinness 5-9 years:
# -----------------------------------------
# The score threshold is: 1.0
# Number of outliers is: 0
# The score threshold is: 1.5
# Number of outliers is: 0
# The score threshold is: 2.0
# Number of outliers is: 0
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0

# %% [markdown]
# I plotted the outlier variables' **np.log**,**winsorized**, and **boxcox** transformations to identify which made the variable's distribution closest to normal. I tested **'normality'** by using tests: jarque-bera and normality.

# %%
winsorized_adult_mortality = winsorize(life_df["adult mortality"],(0,0.10))
adult_mortality_boxcox,_ = boxcox(life_df["adult mortality"])

plt.figure(figsize = (15,15))

plt.subplot(3,3,1)
plt.hist(life_df["adult mortality"])
plt.title("Histogram of adult mortality")

plt.subplot(3,3,2)
plt.hist(np.log(life_df["adult mortality"]))
plt.title("Histogram of log transformed adult mortality")

plt.subplot(3,3,3)
plt.hist(winsorized_adult_mortality)
plt.title("Histogram of winsorized adult mortality")

plt.subplot(3,3,4)
plt.hist(adult_mortality_boxcox)
plt.title("Histogram of adult mortality(boxcox transformed)")
plt.show()

# %%
jb_stats = jarque_bera(adult_mortality_boxcox)
norm_stats = normaltest(adult_mortality_boxcox)

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_stats[0], jb_stats[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_stats[0], norm_stats[1]))
# Out:
# Jarque-Bera test statistics is 15.138904699409734 and p value is 0.0005159749450817097
# Normality test statistics is 19.523019261362066 and p value is 5.762756010318256e-05

# %%
winsorized_gdp = winsorize(life_df["gdp"],(0,0.10))
gdp_boxcox,_ = boxcox(life_df["gdp"])

plt.figure(figsize = (15,15))

plt.subplot(3,3,1)
plt.hist(life_df["gdp"])
plt.title("Histogram of GDP")

plt.subplot(3,3,2)
plt.hist(np.log(life_df["gdp"]))
plt.title("Histogram of log transformed GDP")

plt.subplot(3,3,3)
plt.hist(winsorized_gdp)
plt.title("Histogram of winsorized GDP")

plt.subplot(3,3,4)
plt.hist(gdp_boxcox)
plt.title("Histogram of GDP (boxcox transformed)")

plt.show()

# %%
jb_stats = jarque_bera(gdp_boxcox)
norm_stats = normaltest(gdp_boxcox)

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_stats[0], jb_stats[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_stats[0], norm_stats[1]))
# Out:
# Jarque-Bera test statistics is 0.3098409281223395 and p value is 0.8564832959776815
# Normality test statistics is 0.37501544406317205 and p value is 0.8290227164160813

# %%
winsorized_population = winsorize(life_df["population"],(0,0.10))
population_boxcox,_ = boxcox(life_df["population"])

plt.figure(figsize = (15,15))

plt.subplot(3,3,1)
plt.hist(life_df["population"])
plt.title("Histogram of Population")

plt.subplot(3,3,2)
plt.hist(np.log(life_df["population"]))
plt.title("Histogram of log transformed Population")

plt.subplot(3,3,3)
plt.hist(winsorized_population)
plt.title("Histogram of winsorized Population")

plt.subplot(3,3,4)
plt.hist(population_boxcox)
plt.title("Histogram of Population (boxcox transformed)")

plt.show()

# %%
jb_stats = jarque_bera(population_boxcox)
norm_stats = normaltest(population_boxcox)

print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_stats[0], jb_stats[1]))
print("Normality test statistics is {0} and p value is {1}".format(norm_stats[0], norm_stats[1]))
# Out:
# Jarque-Bera test statistics is 2.002232917978157 and p value is 0.36746894805445385
# Normality test statistics is 1.9643286060696217 and p value is 0.3744996902849025

# %% [markdown]
# I compared the categorical variables and created a **dummy variable** from the variable status.

# %%
count_table = pd.crosstab(life_df["status"], life_df["country"])

# %%
sns.countplot(y="status", hue="status", data=life_df, palette="Greens_d")
plt.show()

# %%
print(stats.chisquare(count_table, axis=None))
# Out:
# Power_divergenceResult(statistic=3218.2927161334237, pvalue=0.0)

# %%
life_df = pd.concat([life_df, pd.get_dummies(life_df["status"],drop_first=True)], axis=1)

# %%
life_df.sample(20)
# Out:
#                                country  year      status  life expectancy  \
# 893                           Ethiopia  2005  Developing             56.0
# 1983                  Papua New Guinea  2008  Developing             61.4
# 2325                         Singapore  2004   Developed             79.7
# 1366                             Kenya  2012  Developing             62.1
# 2127                           Romania  2008   Developed             73.1
# 323             Bosnia and Herzegovina  2013  Developing             77.0
# 308   Bolivia (Plurinational State of)  2012  Developing             69.8
# 1855                       New Zealand  2006   Developed             79.9
# 851                            Eritrea  2015  Developing             64.7
# 2161                            Rwanda  2006  Developing             57.6
# 2407                      South Africa  2001  Developing             56.0
# 1310                           Jamaica  2004  Developing             73.3
# 1216                         Indonesia  2002  Developing             66.7
# 30                             Albania  2001  Developing             73.6
# 2638                             Tonga  2010  Developing             72.8
# 739                            Denmark  2013   Developed             81.0
# 43                             Algeria  2005  Developing             72.9
# 2779       United Republic of Tanzania  2014  Developing             67.0
# 1993                          Paraguay  2014  Developing             73.9
# 2215                             Samoa  2001  Developing             75.0
#
#       adult mortality  infant deaths  alcohol  percentage expenditure  \
# 893             343.0            206    0.990               18.037531
# 1983             29.0             11    0.810              103.727773
# 2325             71.0              0    1.450              204.248189
# 1366            263.0             59    1.810              154.226970
# 2127            159.0              2   11.900              128.080570
# 323               9.0              0    4.120               75.610629
# 308             194.0              8    3.890                0.000000
# 1855             76.0              0    9.340              496.222801
# 851             255.0              5    3.755                0.000000
# 2161            328.0             22    6.880               78.470202
# 2407            429.0             52    7.380              365.258572
# 1310            165.0              1    3.670              192.322631
# 1216            189.0            177    0.050               43.178673
# 30               14.0              1    4.250               96.205571
# 2638            142.0              0    1.240              471.830767
# 739              75.0              0    9.500            10261.763000
# 43              136.0             19    0.500                2.548923
# 2779             34.0             86    0.010                0.000000
# 1993            147.0              3    0.010              561.768470
# 2215            175.0              0    3.430              199.411832
#
#       hepatitis b  measles   bmi  under-five deaths  polio  total expenditure  \
# 893     80.940461      357  13.8                323   56.0            4.20000
# 1983    59.000000        0  43.4                 14   76.0            4.60000
# 2325    94.000000       96  29.9                  0   95.0            3.17000
# 1366    94.000000        0   2.1                 84   94.0            5.49000
# 2127    97.000000       12  55.6                  3   95.0            5.33000
# 323     91.000000        0  54.7                  0   87.0            9.46000
# 308     93.000000        0   5.6                 11   93.0            5.56000
# 1855    87.000000       20  62.6                  0   89.0            8.65000
# 851     95.000000      198  18.6                  7   95.0            5.93819
# 2161    99.000000      494  15.9                 34   99.0            1.20000
# 2407    72.000000     1166   4.9                 76   71.0            8.31000
# 1310    98.000000        0  45.4                  1   97.0            4.80000
# 1216    63.000000    14492  16.7                222    8.0            2.27000
# 30      96.000000       18  46.0                  1   97.0            6.00000
# 2638    82.000000        0  72.7                  0   84.0            4.59000
# 739     80.940461       17  58.1                  0   94.0           11.25000
# 43      83.000000     2302  48.9                 22   88.0            3.24000
# 2779    97.000000       88  23.2                121   97.0            5.58000
# 1993    87.000000        0  49.4                  3   83.0            9.81000
# 2215    89.000000        0  66.5                  0   83.0            5.16000
#
#       diphtheria  hiv/aids           gdp    population  thinness  1-19 years  \
# 893         44.0       3.7    161.626625  7.672783e+06                  11.5
# 1983        63.0       1.3   1178.724690  6.787187e+06                   1.4
# 2325        95.0       0.1   2745.271360  1.275338e+07                   2.1
# 1366        94.0       3.0   1155.258200  4.364663e+07                   8.0
# 2127        96.0       0.1   1136.473560  2.537875e+06                   3.1
# 323         89.0       0.1    535.865550  3.649990e+05                   2.4
# 308         93.0       0.1   1766.947595  1.275338e+07                   1.2
# 1855        89.0       0.1   2667.864520  1.275338e+07                   0.3
# 851         95.0       0.4   1766.947595  1.275338e+07                   8.4
# 2161        99.0       6.2    342.365629  9.265800e+04                   6.8
# 2407        71.0      24.0   2681.781000  4.531294e+07                  15.4
# 1310        98.0       2.3   3719.973510  2.728777e+06                   1.9
# 1216         7.0       0.1    899.555686  2.175859e+06                  11.0
# 30          97.0       0.1   1326.973390  3.617300e+04                   2.1
# 2638        82.0       0.1   3547.599750  1.413700e+04                   0.1
# 739         94.0       0.1  61191.192630  5.614932e+06                   1.1
# 43          88.0       0.1     31.122378  3.328844e+07                   6.1
# 2779        97.0       1.4   1766.947595  1.275338e+07                   6.8
# 1993        87.0       0.2   4712.822736  6.552584e+06                   2.0
# 2215        85.0       0.1   1555.474510  1.755660e+05                   0.2
#
#       thinness 5-9 years  income composition of resources  schooling  \
# 893                 11.2                         0.325000   5.800000
# 1983                 1.3                         0.469000   8.900000
# 2325                 2.0                         0.820000  12.700000
# 1366                 7.8                         0.536000  11.100000
# 2127                 3.5                         0.780000  14.700000
# 323                  2.4                         0.735000  14.200000
# 308                  1.1                         0.655000  13.800000
# 1855                 0.3                         0.888000  19.100000
# 851                  8.2                         0.418000   5.000000
# 2161                 6.8                         0.404000   9.300000
# 2407                18.1                         0.629000  13.000000
# 1310                 1.8                         0.689000  11.100000
# 1216                11.1                         0.608000  10.600000
# 30                   2.1                         0.662000  10.600000
# 2638                 0.1                         0.707000  14.400000
# 739                  0.9                         0.924000  18.700000
# 43                   6.0                         0.680000  12.000000
# 2779                 6.6                         0.627551  11.992793
# 1993                 1.9                         0.688000  12.300000
# 2215                 0.2                         0.645000  12.000000
#
#       Developing
# 893            1
# 1983           1
# 2325           0
# 1366           1
# 2127           0
# 323            1
# 308            1
# 1855           0
# 851            1
# 2161           1
# 2407           1
# 1310           1
# 1216           1
# 30             1
# 2638           1
# 739            0
# 43             1
# 2779           1
# 1993           1
# 2215           1

# %% [markdown]
# I used a correlation heat map to give me a good idea of which variables were closely correlated with our **target variable "life expectancy"**.

# %%
corrmat_life = life_df.corr()
plt.figure(figsize=(18,15))

sns.heatmap(corrmat_life, square=True,annot=True,linewidth=.5)
plt.title("Correlation data with one-hot-encoding on'status'")
plt.show()

# %% [markdown]
# I chose these variables because they had correlation values **greater than .50**.

# %%
life_df [["life expectancy","bmi","income composition of resources","schooling"]].corr()
# Out:
#                                  life expectancy       bmi  \
# life expectancy                         1.000000  0.559255
# bmi                                     0.559255  1.000000
# income composition of resources         0.692483  0.479837
# schooling                               0.715066  0.508105
#
#                                  income composition of resources  schooling
# life expectancy                                         0.692483   0.715066
# bmi                                                     0.479837   0.508105
# income composition of resources                         1.000000   0.796207
# schooling                                               0.796207   1.000000
